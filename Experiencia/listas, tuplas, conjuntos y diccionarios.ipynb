# %% [markdown]
# LIST, TUPLE, SET AND DICT

# %%
#Estructuras de datos en Python (data structures in Python)

'''
YA- listas 	     (lists)        -> list
YA- tuplas 	     (tuples)       -> tuple
YA- conjuntos 	 (sets)         -> set
YA- diccionarios (dictionaries) -> dict
'''

lista_vocales=["a",     "e",   "i", "o","u"] # lista
print(lista_vocales)

tupla_vocales = ("a", "e", "i", "o", "u") # tupla
print(tupla_vocales)


conjunto_vocales                    =                            {"a","e","i","o","u"} # conjunto (elementos únicos: : no importa el órden)
print(conjunto_vocales)
# asi puede salir en pantalla: {'a', 'e', 'u', 'o', 'i'} y cambia cada vez que se ejecuta porque no importa el orden en los conjuntos
# Los connjuntos sestán definidos tal cual como en matemáticas, por ejemplo, se cumplen las poropiedades y operaciones como unión, intersección, diferencia, diferencia simétrica y complemento)

#diccionario:
d={"acero":"material","elefante":"animal","iglesia":"recinto","oscar":"premio","utopía":"difícil de alcanzar"}

#"""
#d = {
#
#   "acero"    :  "material"                ,
#   "elefante" :  "animal"                  ,
#   "iglesia"  :  "recinto"                 ,
#   "oscar"    :  "premio"                  ,
#   "utopía"   :  "difícil de alcanzar" }
#"""
print(d)
# asi sale en pantalla: {"acero":"material","elefante":"animal","iglesia":"recinto","oscar":"premio","utopía":"difícil de alcanzar"}


#"""
#TAREA: hasta las 9:35 pm

#0) (**opcional:casa) Usar el ciclo while en el menú de la calculadora para salirse
#*1) (*clase*) Inventarse su propio ejemplo en Python (Google Colab) de:
#   - Lista, tupla, conjunto, diccionario
#   -(clase/casa) Recorrer cada estructura con un cliclo for
#(CONSULTA: Ayuda: https://www.w3schools.com/)
#2) (opcional:casa) Inventarse un programa que use todo lo que se ha visto hasta ahora:
#   ejemplo: triqui, ahorcado, tienda, notas de la universidad, datos de clientes, etc...
#
#"""

# %%
# LISTA: Nombres de personas
nombres = ["María", "José", "Ana", "Luis", "Camilo", "María"]
print("Lista de nombres:")
for nombre in nombres:
    print(f"- {nombre}")

# TUPLA: Números de cédula NO se pueden modificar
cedulas = (1122334455, 2233445566, 3344556677, 4455667788, 5566778899,6677897650)
print("\n  Tupla de números de cédula:")
for cedula in cedulas:
    print(f"- {cedula}")

# CONJUNTO: Municipios de residencia
municipios_cauca = {"Popayán", "Santander de Quilichao", "Puerto Tejada", "Silvia","Popayán"}
print("\nConjunto de municipios del Cauca:")
for municipio in municipios_cauca:
    print(f"- {municipio}")

# DICCIONARIO: Persona con su profesión 
personas = {
    "María": "Enfermera",
    "José": "Médico",
    "Ana": "Trabajadora social",
    "Luis": "Auxiliar administrativo",
    "Camilo": "Odontólogo"
}
print("\nDiccionario de personas y sus profesiones:")
for nombre in personas:
    print(f"- {nombre} es {personas[nombre]}")

# %% [markdown]
# ""# JUEGO MÁGICO DE HECHIZOS EN PYTHON
# # Por: Oscar Eduardo Tobar Alarcon
# # Este juego aplica conocimientos del bootcamp: listas, tuplas, diccionarios, ciclos, condicionales, funciones, entrada de datos, etc.

# %%
# Introducción y explicación:
print("""
Bienvenido al Juego Mágico de Hechizos 🧙‍♂️✨

- Eres un mago enfrentando a un enemigo oscuro.
- Ambos inician con 100 puntos de salud.
- Puedes usar hechizos para atacar o defenderte.
- Cada hechizo tiene un número limitado de usos, excepto el hechizo especial "revelar".
- "revelar" te muestra la salud tuya y del enemigo, y la cantidad de hechizos que te quedan.
- El hechizo "suerte" tiene efectos diferentes dependiendo de tu nombre de mago.
- El enemigo también atacará dependiendo de tu nombre de mago.
- ¡Derrota al enemigo antes de que él te derrote a ti!
""")

# Solicita el nombre del jugador
nombre_mago = input("¿Cuál es el nombre de tu mago?: ")
print(f"\n¡Saludos, {nombre_mago}! Tu aventura comienza ahora.\n")

# Variables principales
salud_jugador = 100
salud_enemigo = 100

# Diccionario con los hechizos y sus usos permitidos (excepto 'revelar')
hechizos = {
    "fuego": 3,
    "curar": 3,
    "rayo": 2,
    "suerte": 2,
}

# Lista de efectos posibles del hechizo suerte simulando con el nombre del mago
efectos_suerte = ["curar", "x2", "contraataque"]
indice_suerte = 0  # control del uso basado en nombre
indice_ataque_enemigo = 0  # para controlar daño del enemigo con letras del nombre

# Función para mostrar el estado actual
def mostrar_estado():
    print("\nEstado actual:")
    print(f"Salud de {nombre_mago}: {salud_jugador}")
    print(f"Salud del enemigo: {salud_enemigo}")
    print("Hechizos disponibles:")
    for h in hechizos:
        print("-", h, ":", hechizos[h], "uso(s) restante(s)")
    print("- revelar: ilimitado\n")

# Bucle principal
while salud_jugador > 0 and salud_enemigo > 0:
    hechizo = input("Escribe un hechizo (fuego, rayo, curar, suerte o revelar): ").lower()

    if hechizo == "revelar":
        mostrar_estado()
        continue  # no consume turno

    if hechizo not in hechizos:
        print("Hechizo no reconocido. Intenta de nuevo.\n")
        continue

    if hechizos[hechizo] == 0:
        print("Ya no puedes usar ese hechizo.\n")
        continue

    # Uso de hechizo válido, se descuenta 1 uso
    hechizos_restantes = hechizos[hechizo]
    hechizos_restantes = hechizos_restantes - 1
    hechizos[hechizo] = hechizos_restantes  # Se guarda la nueva cantidad

    if hechizo == "fuego":
        print(f"🔥 {nombre_mago} lanza una bola de fuego. El enemigo pierde 20 puntos.")
        salud_enemigo = salud_enemigo - 20

    elif hechizo == "rayo":
        print(f"⚡ {nombre_mago} lanza un rayo. El enemigo pierde 30 puntos.")
        salud_enemigo = salud_enemigo - 30

    elif hechizo == "curar":
        print(f"💚 {nombre_mago} lanza un hechizo de curación y recupera 15 puntos.")
        salud_jugador = salud_jugador + 15
        if salud_jugador > 100:
            salud_jugador = 100

    elif hechizo == "suerte":
        if indice_suerte < len(nombre_mago):
            letra = nombre_mago[indice_suerte].lower()
            indice_suerte += 1
        else:
            letra = "x"  # por defecto si ya no hay más letras

        print(f"✨ Invocaste el hechizo de la SUERTE '...")

        if letra in ["a", "e", "i", "o", "u"]:
            print("🩹 ¡La suerte te sonríe! Recuperas 25 puntos de salud.")
            salud_jugador = salud_jugador + 25
            if salud_jugador > 100:
                salud_jugador = 100

        elif letra in ["x", "y", "z"]:
            print("🔁 ¡Contraataque! Devuelves 30 puntos de daño al enemigo.")
            salud_enemigo = salud_enemigo - 30

        elif indice_suerte % 2 == 0:
            print("💥 ¡Daño doble activado! El enemigo pierde 40 puntos.")
            salud_enemigo = salud_enemigo - 40

        else:
            print("🔁 ¡Contraataque! Devuelves 30 puntos de daño al enemigo.")
            salud_enemigo = salud_enemigo - 30

    # Turno del enemigo (solo ataca si aún está vivo)
    if salud_enemigo > 0:
        if indice_ataque_enemigo < len(nombre_mago):
            letra_enemigo = nombre_mago[indice_ataque_enemigo].lower()
            indice_ataque_enemigo += 1
        else:
            letra_enemigo = "x"  # por defecto

        if letra_enemigo in ["a", "e", "i", "o", "u"]:
            daño = 15
        elif letra_enemigo in ["l", "m", "n"]:
            daño = 30
        else:
            daño = 20

        print(f"\n🧟 El enemigo lanza un ataque oscuro '. Pierdes {daño} puntos.")
        salud_jugador = salud_jugador - daño

    print("-"*40)  # Separador visual

# Resultado final
print("\n🎉 ¡Fin del combate! 🎉")
if salud_jugador > 0:
    print(f"🏆 {nombre_mago} ha derrotado al enemigo. ¡Felicidades!")
else:
    print("☠️ Has sido derrotado por el enemigo. Inténtalo de nuevo...")
# Out:
# Bienvenido al Juego Mágico de Hechizos 🧙‍♂️✨
#
# - Eres un mago enfrentando a un enemigo oscuro.
# - Ambos inician con 100 puntos de salud.
# - Puedes usar hechizos para atacar o defenderte.
# - Cada hechizo tiene un número limitado de usos, excepto el hechizo especial "revelar".
# - "revelar" te muestra la salud tuya y del enemigo, y la cantidad de hechizos que te quedan.
# - El hechizo "suerte" tiene efectos diferentes dependiendo de tu nombre de mago.
# - El enemigo también atacará dependiendo de tu nombre de mago.
# - ¡Derrota al enemigo antes de que él te derrote a ti!
#
#
# ¡Saludos, Samuel! Tu aventura comienza ahora.
#
#
# Estado actual:
# Salud de Samuel: 100
# Salud del enemigo: 100
# Hechizos disponibles:
# - fuego : 3 uso(s) restante(s)
# - curar : 3 uso(s) restante(s)
# - rayo : 2 uso(s) restante(s)
# - suerte : 2 uso(s) restante(s)
# - revelar: ilimitado
#
#
# Estado actual:
# Salud de Samuel: 100
# Salud del enemigo: 100
# Hechizos disponibles:
# ...
